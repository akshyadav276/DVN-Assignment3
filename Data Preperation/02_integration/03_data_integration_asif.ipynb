# %% [markdown]
# # 03 Data Integration\n\nOwner: Muhammad Asif\n\nPurpose: join cleaned BITRE, population, and weather files into Tableau-ready datasets with validated join keys.

# %%
# Add integration code here\n
