# %% [markdown]
# # 04 Exploratory Data Analysis\n\nOwner: Karthik Ramesh\n\nPurpose: identify the strongest dashboard story using historical trends, population-adjusted risk, time patterns, road-user exposure, and intervention segments.

# %%
# Add EDA code here\n
